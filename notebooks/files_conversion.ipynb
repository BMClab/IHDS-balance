# %% [markdown]
# # IDS_balance project
#
# > **file conversion: metadata and individual files to a single pandas dataframe**
#
# This notebook demonstrates how to convert the metadata file and all data files of a dataset to a single dataframe.
# The following datasets have been converted in this way:
#  - Santos16: 11_580_000 rows × 73 columns; 1.6 GB in memory; 800 MB parquet file
#  - dosSantos17: 3_542_700 rows × 270 columns; 6.5 GB in memory; 5.4 GB parquet file

# %% [markdown]
# ## Setup

# %%
import sys, os, glob, datetime
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm import tqdm

print(f'Python {sys.version} on {sys.platform}',
      f' numpy {np.__version__}', f' pandas {pd.__version__}',
      datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S"), sep='\n')
# Out:
# Python 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)] on win32
#  numpy 1.26.2
#  pandas 2.1.3
# 13/04/2024 10:44:09

# %% [markdown]
# ## Santos16 dataset

# %% [markdown]
# ### Dataset location

# %%
# LOCAL
path2 = Path(f'.{os.sep}..{os.sep}Santos16{os.sep}data')
print(f'Dataset location: {path2}')
# Out:
# Dataset location: ../Santos16/data

# %% [markdown]
# ### Load metadata

# %%
metadata = pd.read_csv(f'{path2}{os.sep}{'BDSinfo.txt'}', sep='\t', header=0,
                       engine='c', encoding='utf-8')
print('Information from %s files successfully loaded (total of %s subjects).'
      %(len(metadata), len(pd.unique(metadata.Subject))))
display(metadata)
# Out:
# Information from 1930 files successfully loaded (total of 163 subjects).
#          Trial  Subject  Vision Surface        Age AgeGroup Gender  Height  \
# 0     BDS00001        1    Open    Firm  33.000000    Young      F   157.5
# 1     BDS00002        1    Open    Firm  33.000000    Young      F   157.5
# 2     BDS00003        1    Open    Firm  33.000000    Young      F   157.5
# 3     BDS00004        1  Closed    Firm  33.000000    Young      F   157.5
# 4     BDS00005        1  Closed    Firm  33.000000    Young      F   157.5
# ...        ...      ...     ...     ...        ...      ...    ...     ...
# 1925  BDS01952      163    Open    Firm  25.416667    Young      M   172.0
# 1926  BDS01953      163    Open    Firm  25.416667    Young      M   172.0
# 1927  BDS01954      163  Closed    Foam  25.416667    Young      M   172.0
# 1928  BDS01955      163  Closed    Foam  25.416667    Young      M   172.0
# 1929  BDS01956      163  Closed    Foam  25.416667    Young      M   172.0
#
#       Weight        BMI  ...  Best_7 Best_8 Best_9  Best_10 Best_11 Best_12  \
# 0       54.2  21.849332  ...       2      2      2        2       2       2
# 1       54.2  21.849332  ...       2      2      2        2       2       2
# 2       54.2  21.849332  ...       2      2      2        2       2       2
# 3       54.2  21.849332  ...       2      2      2        2       2       2
# 4       54.2  21.849332  ...       2      2      2        2       2       2
# ...      ...        ...  ...     ...    ...    ...      ...     ...     ...
# 1925    74.6  25.216333  ...       2      2      2        2       2       2
# 1926    74.6  25.216333  ...       2      2      2        2       2       2
# 1927    74.6  25.216333  ...       2      2      2        2       2       2
# 1928    74.6  25.216333  ...       2      2      2        2       2       2
# 1929    74.6  25.216333  ...       2      2      2        2       2       2
#
#      Best_13  Best_14 Best_T                     Date
# 0          2        1     25  2015-10-08 08:30:00.000
# 1          2        1     25  2015-10-08 08:30:00.000
# 2          2        1     25  2015-10-08 08:30:00.000
# 3          2        1     25  2015-10-08 08:30:00.000
# 4          2        1     25  2015-10-08 08:30:00.000
# ...      ...      ...    ...                      ...
# 1925       2        2     26  2016-03-11 10:49:57.538
# 1926       2        2     26  2016-03-11 10:49:57.538
# 1927       2        2     26  2016-03-11 10:49:57.538
# 1928       2        2     26  2016-03-11 10:49:57.538
# 1929       2        2     26  2016-03-11 10:49:57.538
#
# [1930 rows x 64 columns]

# %%
metadata.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1930 entries, 0 to 1929
# Data columns (total 64 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Trial              1930 non-null   object
#  1   Subject            1930 non-null   int64
#  2   Vision             1930 non-null   object
#  3   Surface            1930 non-null   object
#  4   Age                1930 non-null   float64
#  5   AgeGroup           1930 non-null   object
#  6   Gender             1930 non-null   object
#  7   Height             1930 non-null   float64
#  8   Weight             1930 non-null   float64
#  9   BMI                1930 non-null   float64
#  10  FootLen            1906 non-null   float64
#  11  Nationality        1930 non-null   object
#  12  SkinColor          1930 non-null   object
#  13  Ystudy             1930 non-null   int64
#  14  Footwear           1930 non-null   object
#  15  Illness            1930 non-null   object
#  16  Illness2           1930 non-null   object
#  17  Nmedication        1930 non-null   int64
#  18  Medication         1930 non-null   object
#  19  Ortho-Prosthesis   1930 non-null   object
#  20  Ortho-Prosthesis2  1930 non-null   object
#  21  Disability         1930 non-null   object
#  22  Disability2        1930 non-null   object
#  23  Falls12m           1930 non-null   int64
#  24  FES_1              1930 non-null   int64
#  25  FES_2              1930 non-null   int64
#  26  FES_3              1930 non-null   int64
#  27  FES_4              1930 non-null   int64
#  28  FES_5              1930 non-null   int64
#  29  FES_6              1930 non-null   int64
#  30  FES_7              1930 non-null   int64
#  31  FES_T              1930 non-null   int64
#  32  FES_S              1930 non-null   object
#  33  IPAQ_1a            1930 non-null   float64
#  34  IPAQ_1b            1930 non-null   float64
#  35  IPAQ_2a            1930 non-null   int64
#  36  IPAQ_2b            1930 non-null   int64
#  37  IPAQ_3a            1930 non-null   float64
#  38  IPAQ_3b            1930 non-null   float64
#  39  IPAQ_4a            1930 non-null   object
#  40  IPAQ_4b            1930 non-null   object
#  41  IPAQ_S             1930 non-null   object
#  42  TMT_timeA          1930 non-null   float64
#  43  TMT_errorsA        1926 non-null   float64
#  44  TMT_timeB          1930 non-null   float64
#  45  TMT_errorsB        1878 non-null   float64
#  46  Best_1             1930 non-null   int64
#  47  Best_2             1930 non-null   int64
#  48  Best_3l            1930 non-null   int64
#  49  Best_3r            1930 non-null   int64
#  50  Best_4             1930 non-null   int64
#  51  Best_5             1930 non-null   int64
#  52  Best_6l            1930 non-null   int64
#  53  Best_6r            1930 non-null   int64
#  54  Best_7             1930 non-null   int64
#  55  Best_8             1930 non-null   int64
#  56  Best_9             1930 non-null   int64
#  57  Best_10            1930 non-null   int64
#  58  Best_11            1930 non-null   int64
#  59  Best_12            1930 non-null   int64
#  60  Best_13            1930 non-null   int64
#  61  Best_14            1930 non-null   int64
#  62  Best_T             1930 non-null   int64
#  63  Date               1930 non-null   object
# dtypes: float64(13), int64(31), object(20)
# memory usage: 2.8 MB

# %% [markdown]
# ### Set variables type as categorical
#
# See https://pandas.pydata.org/docs/user_guide/categorical.html

# %%
metadata = metadata.astype('category', copy=True)
metadata.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1930 entries, 0 to 1929
# Data columns (total 64 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Trial              1930 non-null   category
#  1   Subject            1930 non-null   category
#  2   Vision             1930 non-null   category
#  3   Surface            1930 non-null   category
#  4   Age                1930 non-null   category
#  5   AgeGroup           1930 non-null   category
#  6   Gender             1930 non-null   category
#  7   Height             1930 non-null   category
#  8   Weight             1930 non-null   category
#  9   BMI                1930 non-null   category
#  10  FootLen            1906 non-null   category
#  11  Nationality        1930 non-null   category
#  12  SkinColor          1930 non-null   category
#  13  Ystudy             1930 non-null   category
#  14  Footwear           1930 non-null   category
#  15  Illness            1930 non-null   category
#  16  Illness2           1930 non-null   category
#  17  Nmedication        1930 non-null   category
#  18  Medication         1930 non-null   category
#  19  Ortho-Prosthesis   1930 non-null   category
#  20  Ortho-Prosthesis2  1930 non-null   category
#  21  Disability         1930 non-null   category
#  22  Disability2        1930 non-null   category
#  23  Falls12m           1930 non-null   category
#  24  FES_1              1930 non-null   category
#  25  FES_2              1930 non-null   category
#  26  FES_3              1930 non-null   category
#  27  FES_4              1930 non-null   category
#  28  FES_5              1930 non-null   category
#  29  FES_6              1930 non-null   category
#  30  FES_7              1930 non-null   category
#  31  FES_T              1930 non-null   category
#  32  FES_S              1930 non-null   category
#  33  IPAQ_1a            1930 non-null   category
#  34  IPAQ_1b            1930 non-null   category
#  35  IPAQ_2a            1930 non-null   category
#  36  IPAQ_2b            1930 non-null   category
#  37  IPAQ_3a            1930 non-null   category
#  38  IPAQ_3b            1930 non-null   category
#  39  IPAQ_4a            1930 non-null   category
#  40  IPAQ_4b            1930 non-null   category
#  41  IPAQ_S             1930 non-null   category
#  42  TMT_timeA          1930 non-null   category
#  43  TMT_errorsA        1926 non-null   category
#  44  TMT_timeB          1930 non-null   category
#  45  TMT_errorsB        1878 non-null   category
#  46  Best_1             1930 non-null   category
#  47  Best_2             1930 non-null   category
#  48  Best_3l            1930 non-null   category
#  49  Best_3r            1930 non-null   category
#  50  Best_4             1930 non-null   category
#  51  Best_5             1930 non-null   category
#  52  Best_6l            1930 non-null   category
#  53  Best_6r            1930 non-null   category
#  54  Best_7             1930 non-null   category
#  55  Best_8             1930 non-null   category
#  56  Best_9             1930 non-null   category
#  57  Best_10            1930 non-null   category
#  58  Best_11            1930 non-null   category
#  59  Best_12            1930 non-null   category
#  60  Best_13            1930 non-null   category
#  61  Best_14            1930 non-null   category
#  62  Best_T             1930 non-null   category
#  63  Date               1930 non-null   category
# dtypes: category(64)
# memory usage: 405.4 KB

# %% [markdown]
# ### Merge metadata and data files individually and then concatenate all

# %%
def merge_meta_data(metadata, trial):
    # Merge metadata and data files
    data = pd.read_csv(f'{path2}{os.sep}{trial + '.txt'}', delimiter='\t', engine='c')
    data['Trial'] = trial
    return pd.merge(metadata.query('Trial == @trial'), data, how='inner', on='Trial')

# %%
df_all = [merge_meta_data(metadata, trial) for trial in tqdm(metadata['Trial'])]
df_all = pd.concat(df_all, ignore_index=True)
df_all = df_all.astype({'Trial': 'category'})
df_all
# Out:
# 100%|████████████████████████████████████████████████████████████████| 1930/1930 [00:42<00:00, 44.92it/s]
#              Trial Subject  Vision Surface        Age AgeGroup Gender Height  \
# 0         BDS00001       1    Open    Firm  33.000000    Young      F  157.5
# 1         BDS00001       1    Open    Firm  33.000000    Young      F  157.5
# 2         BDS00001       1    Open    Firm  33.000000    Young      F  157.5
# 3         BDS00001       1    Open    Firm  33.000000    Young      F  157.5
# 4         BDS00001       1    Open    Firm  33.000000    Young      F  157.5
# ...            ...     ...     ...     ...        ...      ...    ...    ...
# 11579995  BDS01956     163  Closed    Foam  25.416667    Young      M  172.0
# 11579996  BDS01956     163  Closed    Foam  25.416667    Young      M  172.0
# 11579997  BDS01956     163  Closed    Foam  25.416667    Young      M  172.0
# 11579998  BDS01956     163  Closed    Foam  25.416667    Young      M  172.0
# 11579999  BDS01956     163  Closed    Foam  25.416667    Young      M  172.0
#
#          Weight        BMI  ...                     Date Time[s]     Fx[N]  \
# 0          54.2  21.849332  ...  2015-10-08 08:30:00.000    0.01 -1.633567
# 1          54.2  21.849332  ...  2015-10-08 08:30:00.000    0.02 -1.631645
# 2          54.2  21.849332  ...  2015-10-08 08:30:00.000    0.03 -1.628593
# 3          54.2  21.849332  ...  2015-10-08 08:30:00.000    0.04 -1.623200
# 4          54.2  21.849332  ...  2015-10-08 08:30:00.000    0.05 -1.613998
# ...         ...        ...  ...                      ...     ...       ...
# 11579995   74.6  25.216333  ...  2016-03-11 10:49:57.538   59.96  7.559660
# 11579996   74.6  25.216333  ...  2016-03-11 10:49:57.538   59.97  7.408137
# 11579997   74.6  25.216333  ...  2016-03-11 10:49:57.538   59.98  6.770478
# 11579998   74.6  25.216333  ...  2016-03-11 10:49:57.538   59.99  5.685936
# 11579999   74.6  25.216333  ...  2016-03-11 10:49:57.538   60.00  4.331225
#
#              Fy[N]       Fz[N]    Mx[Nm]     My[Nm]    Mz[Nm]  COPx[cm]  \
# 0        -3.739135  539.066061  5.383505  43.064851 -0.570876 -7.988789
# 1        -3.755459  538.591198  5.373275  43.020015 -0.575349 -7.987508
# 2        -3.762146  538.207318  5.367719  42.974805 -0.578670 -7.984805
# 3        -3.753010  537.977214  5.369522  42.929275 -0.580162 -7.979757
# 4        -3.727238  537.915946  5.378311  42.883767 -0.579954 -7.972206
# ...            ...         ...       ...        ...       ...       ...
# 11579995 -1.264583  736.066905 -5.914619 -17.292192 -0.201874  2.349269
# 11579996 -1.169381  736.342291 -5.750486 -17.088347 -0.225570  2.320707
# 11579997 -0.808862  738.143537 -5.428087 -16.605555 -0.279714  2.249638
# 11579998 -0.229957  741.306461 -4.964806 -15.876418 -0.360510  2.141681
# 11579999  0.469068  745.268553 -4.418164 -14.999979 -0.457224  2.012694
#
#           COPy[cm]
# 0         0.998673
# 1         0.997654
# 2         0.997333
# 3         0.998095
# 4         0.999842
# ...            ...
# 11579995 -0.803544
# 11579996 -0.780953
# 11579997 -0.735370
# 11579998 -0.669737
# 11579999 -0.592828
#
# [11580000 rows x 73 columns]

# %%
df_all.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11580000 entries, 0 to 11579999
# Data columns (total 73 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Trial              category
#  1   Subject            category
#  2   Vision             category
#  3   Surface            category
#  4   Age                category
#  5   AgeGroup           category
#  6   Gender             category
#  7   Height             category
#  8   Weight             category
#  9   BMI                category
#  10  FootLen            category
#  11  Nationality        category
#  12  SkinColor          category
#  13  Ystudy             category
#  14  Footwear           category
#  15  Illness            category
#  16  Illness2           category
#  17  Nmedication        category
#  18  Medication         category
#  19  Ortho-Prosthesis   category
#  20  Ortho-Prosthesis2  category
#  21  Disability         category
#  22  Disability2        category
#  23  Falls12m           category
#  24  FES_1              category
#  25  FES_2              category
#  26  FES_3              category
#  27  FES_4              category
#  28  FES_5              category
#  29  FES_6              category
#  30  FES_7              category
#  31  FES_T              category
#  32  FES_S              category
#  33  IPAQ_1a            category
#  34  IPAQ_1b            category
#  35  IPAQ_2a            category
#  36  IPAQ_2b            category
#  37  IPAQ_3a            category
#  38  IPAQ_3b            category
#  39  IPAQ_4a            category
#  40  IPAQ_4b            category
#  41  IPAQ_S             category
#  42  TMT_timeA          category
#  43  TMT_errorsA        category
#  44  TMT_timeB          category
#  45  TMT_errorsB        category
#  46  Best_1             category
#  47  Best_2             category
#  48  Best_3l            category
#  49  Best_3r            category
#  50  Best_4             category
#  51  Best_5             category
#  52  Best_6l            category
#  53  Best_6r            category
#  54  Best_7             category
#  55  Best_8             category
#  56  Best_9             category
#  57  Best_10            category
#  58  Best_11            category
#  59  Best_12            category
#  60  Best_13            category
#  61  Best_14            category
#  62  Best_T             category
#  63  Date               category
#  64  Time[s]            float64
#  65  Fx[N]              float64
#  66  Fy[N]              float64
#  67  Fz[N]              float64
#  68  Mx[Nm]             float64
#  69  My[Nm]             float64
#  70  Mz[Nm]             float64
#  71  COPx[cm]           float64
#  72  COPy[cm]           float64
# dtypes: category(64), float64(9)
# memory usage: 1.6 GB

# %% [markdown]
# ### Save data to file
#
# Use engine 'fastparquet' to preserve category data types; see: https://www.practicaldatascience.org/html/parquet.html

# %%
df_all.to_parquet(f'{path2}{os.sep}{"santos16.parquet"}', engine='fastparquet', index=False)  # 820 MB

# %%
#df_all.to_csv(f'{path2}{os.sep}{"santos16.txt"}', sep='\t', float_format=None, index=False)  # interrupted after > 4 GB

# %% [markdown]
# ### Test: load parquet file

# %%
df_all2 = pd.read_parquet(f'{path2}{os.sep}{"santos16.parquet"}', engine='fastparquet')
df_all2
# Out:
#              Trial Subject  Vision Surface        Age AgeGroup Gender Height  \
# 0         BDS00001       1    Open    Firm  33.000000    Young      F  157.5
# 1         BDS00001       1    Open    Firm  33.000000    Young      F  157.5
# 2         BDS00001       1    Open    Firm  33.000000    Young      F  157.5
# 3         BDS00001       1    Open    Firm  33.000000    Young      F  157.5
# 4         BDS00001       1    Open    Firm  33.000000    Young      F  157.5
# ...            ...     ...     ...     ...        ...      ...    ...    ...
# 11579995  BDS01956     163  Closed    Foam  25.416667    Young      M  172.0
# 11579996  BDS01956     163  Closed    Foam  25.416667    Young      M  172.0
# 11579997  BDS01956     163  Closed    Foam  25.416667    Young      M  172.0
# 11579998  BDS01956     163  Closed    Foam  25.416667    Young      M  172.0
# 11579999  BDS01956     163  Closed    Foam  25.416667    Young      M  172.0
#
#          Weight        BMI  ...                     Date Time[s]     Fx[N]  \
# 0          54.2  21.849332  ...  2015-10-08 08:30:00.000    0.01 -1.633567
# 1          54.2  21.849332  ...  2015-10-08 08:30:00.000    0.02 -1.631645
# 2          54.2  21.849332  ...  2015-10-08 08:30:00.000    0.03 -1.628593
# 3          54.2  21.849332  ...  2015-10-08 08:30:00.000    0.04 -1.623200
# 4          54.2  21.849332  ...  2015-10-08 08:30:00.000    0.05 -1.613998
# ...         ...        ...  ...                      ...     ...       ...
# 11579995   74.6  25.216333  ...  2016-03-11 10:49:57.538   59.96  7.559660
# 11579996   74.6  25.216333  ...  2016-03-11 10:49:57.538   59.97  7.408137
# 11579997   74.6  25.216333  ...  2016-03-11 10:49:57.538   59.98  6.770478
# 11579998   74.6  25.216333  ...  2016-03-11 10:49:57.538   59.99  5.685936
# 11579999   74.6  25.216333  ...  2016-03-11 10:49:57.538   60.00  4.331225
#
#              Fy[N]       Fz[N]    Mx[Nm]     My[Nm]    Mz[Nm]  COPx[cm]  \
# 0        -3.739135  539.066061  5.383505  43.064851 -0.570876 -7.988789
# 1        -3.755459  538.591198  5.373275  43.020015 -0.575349 -7.987508
# 2        -3.762146  538.207318  5.367719  42.974805 -0.578670 -7.984805
# 3        -3.753010  537.977214  5.369522  42.929275 -0.580162 -7.979757
# 4        -3.727238  537.915946  5.378311  42.883767 -0.579954 -7.972206
# ...            ...         ...       ...        ...       ...       ...
# 11579995 -1.264583  736.066905 -5.914619 -17.292192 -0.201874  2.349269
# 11579996 -1.169381  736.342291 -5.750486 -17.088347 -0.225570  2.320707
# 11579997 -0.808862  738.143537 -5.428087 -16.605555 -0.279714  2.249638
# 11579998 -0.229957  741.306461 -4.964806 -15.876418 -0.360510  2.141681
# 11579999  0.469068  745.268553 -4.418164 -14.999979 -0.457224  2.012694
#
#           COPy[cm]
# 0         0.998673
# 1         0.997654
# 2         0.997333
# 3         0.998095
# 4         0.999842
# ...            ...
# 11579995 -0.803544
# 11579996 -0.780953
# 11579997 -0.735370
# 11579998 -0.669737
# 11579999 -0.592828
#
# [11580000 rows x 73 columns]

# %%
df_all2.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11580000 entries, 0 to 11579999
# Data columns (total 73 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Trial              category
#  1   Subject            category
#  2   Vision             category
#  3   Surface            category
#  4   Age                category
#  5   AgeGroup           category
#  6   Gender             category
#  7   Height             category
#  8   Weight             category
#  9   BMI                category
#  10  FootLen            category
#  11  Nationality        category
#  12  SkinColor          category
#  13  Ystudy             category
#  14  Footwear           category
#  15  Illness            category
#  16  Illness2           category
#  17  Nmedication        category
#  18  Medication         category
#  19  Ortho-Prosthesis   category
#  20  Ortho-Prosthesis2  category
#  21  Disability         category
#  22  Disability2        category
#  23  Falls12m           category
#  24  FES_1              category
#  25  FES_2              category
#  26  FES_3              category
#  27  FES_4              category
#  28  FES_5              category
#  29  FES_6              category
#  30  FES_7              category
#  31  FES_T              category
#  32  FES_S              category
#  33  IPAQ_1a            category
#  34  IPAQ_1b            category
#  35  IPAQ_2a            category
#  36  IPAQ_2b            category
#  37  IPAQ_3a            category
#  38  IPAQ_3b            category
#  39  IPAQ_4a            category
#  40  IPAQ_4b            category
#  41  IPAQ_S             category
#  42  TMT_timeA          category
#  43  TMT_errorsA        category
#  44  TMT_timeB          category
#  45  TMT_errorsB        category
#  46  Best_1             category
#  47  Best_2             category
#  48  Best_3l            category
#  49  Best_3r            category
#  50  Best_4             category
#  51  Best_5             category
#  52  Best_6l            category
#  53  Best_6r            category
#  54  Best_7             category
#  55  Best_8             category
#  56  Best_9             category
#  57  Best_10            category
#  58  Best_11            category
#  59  Best_12            category
#  60  Best_13            category
#  61  Best_14            category
#  62  Best_T             category
#  63  Date               category
#  64  Time[s]            float64
#  65  Fx[N]              float64
#  66  Fy[N]              float64
#  67  Fz[N]              float64
#  68  Mx[Nm]             float64
#  69  My[Nm]             float64
#  70  Mz[Nm]             float64
#  71  COPx[cm]           float64
#  72  COPy[cm]           float64
# dtypes: category(64), float64(9)
# memory usage: 1.6 GB

# %% [markdown]
# ## dosSantos17 dataset

# %%
# LOCAL marcos
"""path2 = Path(f'.{os.sep}..{os.sep}dosSantos17{os.sep}data')
print(f'Dataset location: {path2}')
metadata = pd.read_csv(f"{path2}{os.sep}{'PDSinfo.txt'}", sep='\t', header=0,
                       engine='c', encoding='utf-8')
print('Information from %s files successfully loaded (total of %s subjects).'
      %(len(metadata), len(pd.unique(metadata.Subject))))
display(metadata)"""
# Out:
#   Cell In[2], line 4
#     metadata = pd.read_csv(f'{path2}{os.sep}{'PDSinfo.txt'}', sep='\t', header=0,
#                                               ^
# SyntaxError: f-string: expecting '}'

# %%
# LOCAL Jonatas
path2 = Path(f'D:{os.sep}Datasets{os.sep}dosSantos17{os.sep}data')
print(f'Dataset location: {path2}')
metadata = pd.read_csv(f"{path2}{os.sep}PDSinfo.txt", sep='\t', header=0,
                       engine='c', encoding='utf-8')
print('Information from %s files successfully loaded (total of %s subjects).'
      %(len(metadata), len(pd.unique(metadata.Subject))))
display(metadata)
# Out:
# Dataset location: D:\Datasets\dosSantos17\data
# Information from 588 files successfully loaded (total of 49 subjects).
#         Trial  Subject  Vision Surface  Rep    Age AgeGroup Gender  Height  \
# 0    PDS01OR1        1    Open   Rigid    1  25.67    Young      M    1.72
# 1    PDS01OR2        1    Open   Rigid    2  25.67    Young      M    1.72
# 2    PDS01OR3        1    Open   Rigid    3  25.67    Young      M    1.72
# 3    PDS01OF1        1    Open    Foam    1  25.67    Young      M    1.72
# 4    PDS01OF2        1    Open    Foam    2  25.67    Young      M    1.72
# ..        ...      ...     ...     ...  ...    ...      ...    ...     ...
# 583  PDS49CR2       49  Closed   Rigid    2  64.92      Old      F    1.58
# 584  PDS49CR3       49  Closed   Rigid    3  64.92      Old      F    1.58
# 585  PDS49CF1       49  Closed    Foam    1  64.92      Old      F    1.58
# 586  PDS49CF2       49  Closed    Foam    2  64.92      Old      F    1.58
# 587  PDS49CF3       49  Closed    Foam    3  64.92      Old      F    1.58
#
#       Mass  ...  Nmedication  \
# 0    74.30  ...            0
# 1    74.30  ...            0
# 2    74.30  ...            0
# 3    74.30  ...            0
# 4    74.30  ...            0
# ..     ...  ...          ...
# 583  60.75  ...            3
# 584  60.75  ...            3
# 585  60.75  ...            3
# 586  60.75  ...            3
# 587  60.75  ...            3
#
#                                             Medication Ortho-Prosthesis  \
# 0                                                   No              Yes
# 1                                                   No              Yes
# 2                                                   No              Yes
# 3                                                   No              Yes
# 4                                                   No              Yes
# ..                                                 ...              ...
# 583  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 584  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 585  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 586  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 587  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
#
#                    Ortho-Prosthesis2 Disability         Disability2 Falls12m  \
# 0                    Corrective lens         No                  No        0
# 1                    Corrective lens         No                  No        0
# 2                    Corrective lens         No                  No        0
# 3                    Corrective lens         No                  No        0
# 4                    Corrective lens         No                  No        0
# ..                               ...        ...                 ...      ...
# 583  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 584  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 585  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 586  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 587  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
#
#     PhysicalActivity        Sequence                     Date
# 0                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 1                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 2                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 3                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 4                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# ..               ...             ...                      ...
# 583                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 584                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 585                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 586                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 587                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
#
# [588 rows x 29 columns]

# %%
# add static trial names to the metadata, so we can loop over it and concatenate to all data
subjects = pd.unique(metadata.Subject).tolist()
for s in subjects[::-1]:
    idx = metadata.query('Subject == @s', engine='python').index[-1]
    metadata.loc[idx + .5] = metadata.loc[idx].values
    metadata.loc[idx + .5, ['Trial', 'Vision', 'Surface', 'Rep']] = ['PDS' + str(s).zfill(2) + 'static', None, None, None]
metadata.sort_index(inplace=True)
metadata.reset_index(drop=True, inplace=True)

# %%
metadata = metadata.astype('category', copy=True)
display(metadata)
display(metadata.info(memory_usage='deep'))
# Out:
#            Trial Subject  Vision Surface  Rep    Age AgeGroup Gender Height  \
# 0       PDS01OR1       1    Open   Rigid  1.0  25.67    Young      M   1.72
# 1       PDS01OR2       1    Open   Rigid  2.0  25.67    Young      M   1.72
# 2       PDS01OR3       1    Open   Rigid  3.0  25.67    Young      M   1.72
# 3       PDS01OF1       1    Open    Foam  1.0  25.67    Young      M   1.72
# 4       PDS01OF2       1    Open    Foam  2.0  25.67    Young      M   1.72
# ..           ...     ...     ...     ...  ...    ...      ...    ...    ...
# 632     PDS49CR3      49  Closed   Rigid  3.0  64.92      Old      F   1.58
# 633     PDS49CF1      49  Closed    Foam  1.0  64.92      Old      F   1.58
# 634     PDS49CF2      49  Closed    Foam  2.0  64.92      Old      F   1.58
# 635     PDS49CF3      49  Closed    Foam  3.0  64.92      Old      F   1.58
# 636  PDS49static      49     NaN     NaN  NaN  64.92      Old      F   1.58
#
#       Mass  ... Nmedication  \
# 0    74.30  ...           0
# 1    74.30  ...           0
# 2    74.30  ...           0
# 3    74.30  ...           0
# 4    74.30  ...           0
# ..     ...  ...         ...
# 632  60.75  ...           3
# 633  60.75  ...           3
# 634  60.75  ...           3
# 635  60.75  ...           3
# 636  60.75  ...           3
#
#                                             Medication Ortho-Prosthesis  \
# 0                                                   No              Yes
# 1                                                   No              Yes
# 2                                                   No              Yes
# 3                                                   No              Yes
# 4                                                   No              Yes
# ..                                                 ...              ...
# 632  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 633  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 634  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 635  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 636  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
#
#                    Ortho-Prosthesis2 Disability         Disability2 Falls12m  \
# 0                    Corrective lens         No                  No        0
# 1                    Corrective lens         No                  No        0
# 2                    Corrective lens         No                  No        0
# 3                    Corrective lens         No                  No        0
# 4                    Corrective lens         No                  No        0
# ..                               ...        ...                 ...      ...
# 632  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 633  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 634  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 635  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 636  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
#
#     PhysicalActivity        Sequence                     Date
# 0                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 1                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 2                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 3                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 4                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# ..               ...             ...                      ...
# 632                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 633                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 634                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 635                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 636                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
#
# [637 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637 entries, 0 to 636
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Trial              637 non-null    category
#  1   Subject            637 non-null    category
#  2   Vision             588 non-null    category
#  3   Surface            588 non-null    category
#  4   Rep                588 non-null    category
#  5   Age                637 non-null    category
#  6   AgeGroup           637 non-null    category
#  7   Gender             637 non-null    category
#  8   Height             637 non-null    category
#  9   Mass               637 non-null    category
#  10  BMI                637 non-null    category
#  11  FootLen            637 non-null    category
#  12  DominantLeg        637 non-null    category
#  13  Nationality        637 non-null    category
#  14  SkinColor          637 non-null    category
#  15  Ystudy             637 non-null    category
#  16  Footwear           637 non-null    category
#  17  Illness            637 non-null    category
#  18  Illness2           637 non-null    category
#  19  Nmedication        637 non-null    category
#  20  Medication         637 non-null    category
#  21  Ortho-Prosthesis   637 non-null    category
#  22  Ortho-Prosthesis2  637 non-null    category
#  23  Disability         637 non-null    category
#  24  Disability2        637 non-null    category
#  25  Falls12m           637 non-null    category
#  26  PhysicalActivity   637 non-null    category
#  27  Sequence           637 non-null    category
#  28  Date               637 non-null    category
# dtypes: category(29)
# memory usage: 106.0 KB
# None

# %%
def merge_meta_and_data(trial, metadata=metadata, kinds=('')):
    # Merge metadata and data files
    #meta_and_data = pd.DataFrame()
    if trial[5:] != 'static':
        for k, kind in enumerate(kinds):
            df = pd.read_csv(f"{path2}{os.sep}{trial + kind + '.txt'}", delimiter='\t', engine='c')  #.iloc[:2, :]
            if k == 0:
                df['Trial'] = trial
                meta_and_data = pd.merge(metadata.query('Trial == @trial'), df, how='inner', on='Trial')
            else:
                df.drop(columns='Time', inplace=True)
                meta_and_data = pd.concat([meta_and_data, df], axis=1)
    else:
        df = pd.read_csv(f'{path2}{os.sep}{trial + '.txt'}', delimiter='\t', engine='c')  # .iloc[:2, :]
        df['Trial'] = trial
        meta_and_data = pd.merge(metadata.query('Trial == @trial'), df, how='inner', on='Trial')
        pass

    return meta_and_data
# Out:
#   Cell In[6], line 6
#     df = pd.read_csv(f'{path2}{os.sep}{trial + kind + '.txt'}', delimiter='\t', engine='c')  #.iloc[:2, :]
#                                                        ^
# SyntaxError: f-string: expecting '}'

# %%
df_all = [merge_meta_and_data(trial, metadata, kinds=('grf', 'ang', 'mkr'))
          for trial in tqdm(metadata['Trial'])]
df_all = pd.concat(df_all, axis=0, ignore_index=True)
df_all = df_all.astype({'Trial': 'category'})
display(df_all)
display(df_all.info(verbose=True, memory_usage='deep'))
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 637/637 [01:26<00:00,  7.32it/s]
#                Trial Subject Vision Surface  Rep    Age AgeGroup Gender  \
# 0           PDS01OR1       1   Open   Rigid  1.0  25.67    Young      M
# 1           PDS01OR1       1   Open   Rigid  1.0  25.67    Young      M
# 2           PDS01OR1       1   Open   Rigid  1.0  25.67    Young      M
# 3           PDS01OR1       1   Open   Rigid  1.0  25.67    Young      M
# 4           PDS01OR1       1   Open   Rigid  1.0  25.67    Young      M
# ...              ...     ...    ...     ...  ...    ...      ...    ...
# 3542695  PDS49static      49    NaN     NaN  NaN  64.92      Old      F
# 3542696  PDS49static      49    NaN     NaN  NaN  64.92      Old      F
# 3542697  PDS49static      49    NaN     NaN  NaN  64.92      Old      F
# 3542698  PDS49static      49    NaN     NaN  NaN  64.92      Old      F
# 3542699  PDS49static      49    NaN     NaN  NaN  64.92      Old      F
#
#         Height   Mass  ... R.Knee.Medial_Z L.Knee.Medial_X L.Knee.Medial_Y  \
# 0         1.72  74.30  ...             NaN             NaN             NaN
# 1         1.72  74.30  ...             NaN             NaN             NaN
# 2         1.72  74.30  ...             NaN             NaN             NaN
# 3         1.72  74.30  ...             NaN             NaN             NaN
# 4         1.72  74.30  ...             NaN             NaN             NaN
# ...        ...    ...  ...             ...             ...             ...
# 3542695   1.58  60.75  ...       -1.194277       -0.386336        0.424990
# 3542696   1.58  60.75  ...       -1.194275       -0.386327        0.424990
# 3542697   1.58  60.75  ...       -1.194271       -0.386312        0.424988
# 3542698   1.58  60.75  ...       -1.194266       -0.386292        0.424984
# 3542699   1.58  60.75  ...       -1.194260       -0.386270        0.424980
#
#         L.Knee.Medial_Z R.Ankle.Medial_X R.Ankle.Medial_Y R.Ankle.Medial_Z  \
# 0                   NaN              NaN              NaN              NaN
# 1                   NaN              NaN              NaN              NaN
# 2                   NaN              NaN              NaN              NaN
# 3                   NaN              NaN              NaN              NaN
# 4                   NaN              NaN              NaN              NaN
# ...                 ...              ...              ...              ...
# 3542695       -1.275723        -0.385735         0.066252        -1.139551
# 3542696       -1.275722        -0.385737         0.066251        -1.139551
# 3542697       -1.275720        -0.385738         0.066249        -1.139549
# 3542698       -1.275716        -0.385739         0.066245        -1.139545
# 3542699       -1.275710        -0.385740         0.066240        -1.139540
#
#         L.Ankle.Medial_X L.Ankle.Medial_Y L.Ankle.Medial_Z
# 0                    NaN              NaN              NaN
# 1                    NaN              NaN              NaN
# 2                    NaN              NaN              NaN
# 3                    NaN              NaN              NaN
# 4                    NaN              NaN              NaN
# ...                  ...              ...              ...
# 3542695        -0.385341         0.068598        -1.317972
# 3542696        -0.385339         0.068597        -1.317970
# 3542697        -0.385336         0.068594        -1.317969
# 3542698        -0.385333         0.068592        -1.317969
# 3542699        -0.385330         0.068590        -1.317970
#
# [3542700 rows x 270 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3542700 entries, 0 to 3542699
# Data columns (total 270 columns):
#  #    Column             Dtype
# ---   ------             -----
#  0    Trial              category
#  1    Subject            category
#  2    Vision             category
#  3    Surface            category
#  4    Rep                category
#  5    Age                category
#  6    AgeGroup           category
#  7    Gender             category
#  8    Height             category
#  9    Mass               category
#  10   BMI                category
#  11   FootLen            category
#  12   DominantLeg        category
#  13   Nationality        category
#  14   SkinColor          category
#  15   Ystudy             category
#  16   Footwear           category
#  17   Illness            category
#  18   Illness2           category
#  19   Nmedication        category
#  20   Medication         category
#  21   Ortho-Prosthesis   category
#  22   Ortho-Prosthesis2  category
#  23   Disability         category
#  24   Disability2        category
#  25   Falls12m           category
#  26   PhysicalActivity   category
#  27   Sequence           category
#  28   Date               category
#  29   Time               float64
#  30   RGRF_X             float64
#  31   RGRF_Y             float64
#  32   RGRF_Z             float64
#  33   LGRF_X             float64
#  34   LGRF_Y             float64
#  35   LGRF_Z             float64
#  36   GRFNET_X           float64
#  37   GRFNET_Y           float64
#  38   GRFNET_Z           float64
#  39   RCOP_X             float64
#  40   RCOP_Y             float64
#  41   RCOP_Z             float64
#  42   LCOP_X             float64
#  43   LCOP_Y             float64
#  44   LCOP_Z             float64
#  45   COPNET_X           float64
#  46   COPNET_Y           float64
#  47   COPNET_Z           float64
#  48   RFREEMOMENT_Y      float64
#  49   LFREEMOMENT_Y      float64
#  50   Sp5_Sp4_FE_Z       float64
#  51   Sp4_Sp3_FE_Z       float64
#  52   Sp3_Sp2_FE_Z       float64
#  53   Sp2_Sp1_FE_Z       float64
#  54   Sp1_Pel_FE_Z       float64
#  55   RSp5_Sp4_LB_Z      float64
#  56   LSp5_Sp4_LB_Z      float64
#  57   RSp4_Sp3_LB_Z      float64
#  58   LSp4_Sp3_LB_Z      float64
#  59   RSp3_Sp2_LB_Z      float64
#  60   LSp3_Sp2_LB_Z      float64
#  61   RSp2_Sp1_LB_Z      float64
#  62   LSp2_Sp1_LB_Z      float64
#  63   RSp1_Pel_LB_Z      float64
#  64   LSp1_Pel_LB_Z      float64
#  65   RSh_Th_LB_Z        float64
#  66   LSh_Th_LB_Z        float64
#  67   RSh_Th_AR_Z        float64
#  68   LSh_Th_AR_Z        float64
#  69   RA_Th_Transl_X     float64
#  70   RA_Th_Transl_Y     float64
#  71   RA_Th_Transl_Z     float64
#  72   LA_Th_Transl_X     float64
#  73   LA_Th_Transl_Y     float64
#  74   LA_Th_Transl_Z     float64
#  75   RHe_Th_Angle_X     float64
#  76   RHe_Th_Angle_Y     float64
#  77   RHe_Th_Angle_Z     float64
#  78   LHe_Th_Angle_X     float64
#  79   LHe_Th_Angle_Y     float64
#  80   LHe_Th_Angle_Z     float64
#  81   RTh_Pel_Angle_X    float64
#  82   RTh_Pel_Angle_Y    float64
#  83   RTh_Pel_Angle_Z    float64
#  84   LTh_Pel_Angle_X    float64
#  85   LTh_Pel_Angle_Y    float64
#  86   LTh_Pel_Angle_Z    float64
#  87   RHe_Lab_Angle_X    float64
#  88   RHe_Lab_Angle_Y    float64
#  89   RHe_Lab_Angle_Z    float64
#  90   LHe_Lab_Angle_X    float64
#  91   LHe_Lab_Angle_Y    float64
#  92   LHe_Lab_Angle_Z    float64
#  93   RTh_Lab_Angle_X    float64
#  94   RTh_Lab_Angle_Y    float64
#  95   RTh_Lab_Angle_Z    float64
#  96   LTh_Lab_Angle_X    float64
#  97   LTh_Lab_Angle_Y    float64
#  98   LTh_Lab_Angle_Z    float64
#  99   RPel_Lab_Angle_X   float64
#  100  RPel_Lab_Angle_Y   float64
#  101  RPel_Lab_Angle_Z   float64
#  102  LPel_Lab_Angle_X   float64
#  103  LPel_Lab_Angle_Y   float64
#  104  LPel_Lab_Angle_Z   float64
#  105  RHip_Angle_X       float64
#  106  RHip_Angle_Y       float64
#  107  RHip_Angle_Z       float64
#  108  LHip_Angle_X       float64
#  109  LHip_Angle_Y       float64
#  110  LHip_Angle_Z       float64
#  111  RKnee_Angle_X      float64
#  112  RKnee_Angle_Y      float64
#  113  RKnee_Angle_Z      float64
#  114  LKnee_Angle_X      float64
#  115  LKnee_Angle_Y      float64
#  116  LKnee_Angle_Z      float64
#  117  RAnkle_Angle_X     float64
#  118  RAnkle_Angle_Y     float64
#  119  RAnkle_Angle_Z     float64
#  120  LAnkle_Angle_X     float64
#  121  LAnkle_Angle_Y     float64
#  122  LAnkle_Angle_Z     float64
#  123  R.Front.Head_X     float64
#  124  R.Front.Head_Y     float64
#  125  R.Front.Head_Z     float64
#  126  L.Front.Head_X     float64
#  127  L.Front.Head_Y     float64
#  128  L.Front.Head_Z     float64
#  129  R.Back.Head_X      float64
#  130  R.Back.Head_Y      float64
#  131  R.Back.Head_Z      float64
#  132  L.Back.Head_X      float64
#  133  L.Back.Head_Y      float64
#  134  L.Back.Head_Z      float64
#  135  R.Shoulder_X       float64
#  136  R.Shoulder_Y       float64
#  137  R.Shoulder_Z       float64
#  138  L.Shoulder_X       float64
#  139  L.Shoulder_Y       float64
#  140  L.Shoulder_Z       float64
#  141  C7_X               float64
#  142  C7_Y               float64
#  143  C7_Z               float64
#  144  T2_X               float64
#  145  T2_Y               float64
#  146  T2_Z               float64
#  147  T7_X               float64
#  148  T7_Y               float64
#  149  T7_Z               float64
#  150  L1_X               float64
#  151  L1_Y               float64
#  152  L1_Z               float64
#  153  L3_X               float64
#  154  L3_Y               float64
#  155  L3_Z               float64
#  156  L5_X               float64
#  157  L5_Y               float64
#  158  L5_Z               float64
#  159  IJ_X               float64
#  160  IJ_Y               float64
#  161  IJ_Z               float64
#  162  PX_X               float64
#  163  PX_Y               float64
#  164  PX_Z               float64
#  165  R.ASIS_X           float64
#  166  R.ASIS_Y           float64
#  167  R.ASIS_Z           float64
#  168  L.ASIS_X           float64
#  169  L.ASIS_Y           float64
#  170  L.ASIS_Z           float64
#  171  R.PSIS_X           float64
#  172  R.PSIS_Y           float64
#  173  R.PSIS_Z           float64
#  174  L.PSIS_X           float64
#  175  L.PSIS_Y           float64
#  176  L.PSIS_Z           float64
#  177  L.Iliac.Crestv_X   float64
#  178  L.Iliac.Crestv_Y   float64
#  179  L.Iliac.Crestv_Z   float64
#  180  R.Iliac.Crestv_X   float64
#  181  R.Iliac.Crestv_Y   float64
#  182  R.Iliac.Crestv_Z   float64
#  183  R.GTR_X            float64
#  184  R.GTR_Y            float64
#  185  R.GTR_Z            float64
#  186  L.GTR_X            float64
#  187  L.GTR_Y            float64
#  188  L.GTR_Z            float64
#  189  R.Knee_X           float64
#  190  R.Knee_Y           float64
#  191  R.Knee_Z           float64
#  192  R.Knee.Medialv_X   float64
#  193  R.Knee.Medialv_Y   float64
#  194  R.Knee.Medialv_Z   float64
#  195  L.Knee_X           float64
#  196  L.Knee_Y           float64
#  197  L.Knee_Z           float64
#  198  L.Knee.Medialv_X   float64
#  199  L.Knee.Medialv_Y   float64
#  200  L.Knee.Medialv_Z   float64
#  201  R.HF_X             float64
#  202  R.HF_Y             float64
#  203  R.HF_Z             float64
#  204  L.HF_X             float64
#  205  L.HF_Y             float64
#  206  L.HF_Z             float64
#  207  R.TT_X             float64
#  208  R.TT_Y             float64
#  209  R.TT_Z             float64
#  210  L.TT_X             float64
#  211  L.TT_Y             float64
#  212  L.TT_Z             float64
#  213  R.Ankle_X          float64
#  214  R.Ankle_Y          float64
#  215  R.Ankle_Z          float64
#  216  R.Ankle.Medialv_X  float64
#  217  R.Ankle.Medialv_Y  float64
#  218  R.Ankle.Medialv_Z  float64
#  219  L.Ankle_X          float64
#  220  L.Ankle_Y          float64
#  221  L.Ankle_Z          float64
#  222  L.Ankle.Medialv_X  float64
#  223  L.Ankle.Medialv_Y  float64
#  224  L.Ankle.Medialv_Z  float64
#  225  R.Heel_X           float64
#  226  R.Heel_Y           float64
#  227  R.Heel_Z           float64
#  228  L.Heel_X           float64
#  229  L.Heel_Y           float64
#  230  L.Heel_Z           float64
#  231  R.MT1_X            float64
#  232  R.MT1_Y            float64
#  233  R.MT1_Z            float64
#  234  R.MT2_X            float64
#  235  R.MT2_Y            float64
#  236  R.MT2_Z            float64
#  237  R.MT5_X            float64
#  238  R.MT5_Y            float64
#  239  R.MT5_Z            float64
#  240  L.MT1_X            float64
#  241  L.MT1_Y            float64
#  242  L.MT1_Z            float64
#  243  L.MT2_X            float64
#  244  L.MT2_Y            float64
#  245  L.MT2_Z            float64
#  246  L.MT5_X            float64
#  247  L.MT5_Y            float64
#  248  L.MT5_Z            float64
#  249  COG_X              float64
#  250  COG_Y              float64
#  251  COG_Z              float64
#  252  L.Iliac.Crest_X    float64
#  253  L.Iliac.Crest_Y    float64
#  254  L.Iliac.Crest_Z    float64
#  255  R.Iliac.Crest_X    float64
#  256  R.Iliac.Crest_Y    float64
#  257  R.Iliac.Crest_Z    float64
#  258  R.Knee.Medial_X    float64
#  259  R.Knee.Medial_Y    float64
#  260  R.Knee.Medial_Z    float64
#  261  L.Knee.Medial_X    float64
#  262  L.Knee.Medial_Y    float64
#  263  L.Knee.Medial_Z    float64
#  264  R.Ankle.Medial_X   float64
#  265  R.Ankle.Medial_Y   float64
#  266  R.Ankle.Medial_Z   float64
#  267  L.Ankle.Medial_X   float64
#  268  L.Ankle.Medial_Y   float64
#  269  L.Ankle.Medial_Z   float64
# dtypes: category(29), float64(241)
# memory usage: 6.5 GB
# None

# %% [markdown]
# ### Save data to file

# %%
df_all.to_parquet(f'{path2}{os.sep}{"dossantos17.parquet"}', engine='fastparquet', index=False)  # 5.4 GB

# %%
# test it
df_all2 = pd.read_parquet(f'{path2}{os.sep}{"dossantos17.parquet"}', engine='fastparquet')
df_all2
# Out:
#                Trial Subject Vision Surface  Rep    Age AgeGroup Gender  \
# 0           PDS01OR1       1   Open   Rigid  1.0  25.67    Young      M
# 1           PDS01OR1       1   Open   Rigid  1.0  25.67    Young      M
# 2           PDS01OR1       1   Open   Rigid  1.0  25.67    Young      M
# 3           PDS01OR1       1   Open   Rigid  1.0  25.67    Young      M
# 4           PDS01OR1       1   Open   Rigid  1.0  25.67    Young      M
# ...              ...     ...    ...     ...  ...    ...      ...    ...
# 3542695  PDS49static      49    NaN     NaN  NaN  64.92      Old      F
# 3542696  PDS49static      49    NaN     NaN  NaN  64.92      Old      F
# 3542697  PDS49static      49    NaN     NaN  NaN  64.92      Old      F
# 3542698  PDS49static      49    NaN     NaN  NaN  64.92      Old      F
# 3542699  PDS49static      49    NaN     NaN  NaN  64.92      Old      F
#
#         Height   Mass  ... R.Knee.Medial_Z L.Knee.Medial_X L.Knee.Medial_Y  \
# 0         1.72  74.30  ...             NaN             NaN             NaN
# 1         1.72  74.30  ...             NaN             NaN             NaN
# 2         1.72  74.30  ...             NaN             NaN             NaN
# 3         1.72  74.30  ...             NaN             NaN             NaN
# 4         1.72  74.30  ...             NaN             NaN             NaN
# ...        ...    ...  ...             ...             ...             ...
# 3542695   1.58  60.75  ...       -1.194277       -0.386336        0.424990
# 3542696   1.58  60.75  ...       -1.194275       -0.386327        0.424990
# 3542697   1.58  60.75  ...       -1.194271       -0.386312        0.424988
# 3542698   1.58  60.75  ...       -1.194266       -0.386292        0.424984
# 3542699   1.58  60.75  ...       -1.194260       -0.386270        0.424980
#
#         L.Knee.Medial_Z R.Ankle.Medial_X R.Ankle.Medial_Y R.Ankle.Medial_Z  \
# 0                   NaN              NaN              NaN              NaN
# 1                   NaN              NaN              NaN              NaN
# 2                   NaN              NaN              NaN              NaN
# 3                   NaN              NaN              NaN              NaN
# 4                   NaN              NaN              NaN              NaN
# ...                 ...              ...              ...              ...
# 3542695       -1.275723        -0.385735         0.066252        -1.139551
# 3542696       -1.275722        -0.385737         0.066251        -1.139551
# 3542697       -1.275720        -0.385738         0.066249        -1.139549
# 3542698       -1.275716        -0.385739         0.066245        -1.139545
# 3542699       -1.275710        -0.385740         0.066240        -1.139540
#
#         L.Ankle.Medial_X L.Ankle.Medial_Y L.Ankle.Medial_Z
# 0                    NaN              NaN              NaN
# 1                    NaN              NaN              NaN
# 2                    NaN              NaN              NaN
# 3                    NaN              NaN              NaN
# 4                    NaN              NaN              NaN
# ...                  ...              ...              ...
# 3542695        -0.385341         0.068598        -1.317972
# 3542696        -0.385339         0.068597        -1.317970
# 3542697        -0.385336         0.068594        -1.317969
# 3542698        -0.385333         0.068592        -1.317969
# 3542699        -0.385330         0.068590        -1.317970
#
# [3542700 rows x 270 columns]

# %%
df_all2.info(verbose=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3542700 entries, 0 to 3542699
# Data columns (total 270 columns):
#  #    Column             Dtype
# ---   ------             -----
#  0    Trial              category
#  1    Subject            category
#  2    Vision             category
#  3    Surface            category
#  4    Rep                category
#  5    Age                category
#  6    AgeGroup           category
#  7    Gender             category
#  8    Height             category
#  9    Mass               category
#  10   BMI                category
#  11   FootLen            category
#  12   DominantLeg        category
#  13   Nationality        category
#  14   SkinColor          category
#  15   Ystudy             category
#  16   Footwear           category
#  17   Illness            category
#  18   Illness2           category
#  19   Nmedication        category
#  20   Medication         category
#  21   Ortho-Prosthesis   category
#  22   Ortho-Prosthesis2  category
#  23   Disability         category
#  24   Disability2        category
#  25   Falls12m           category
#  26   PhysicalActivity   category
#  27   Sequence           category
#  28   Date               category
#  29   Time               float64
#  30   RGRF_X             float64
#  31   RGRF_Y             float64
#  32   RGRF_Z             float64
#  33   LGRF_X             float64
#  34   LGRF_Y             float64
#  35   LGRF_Z             float64
#  36   GRFNET_X           float64
#  37   GRFNET_Y           float64
#  38   GRFNET_Z           float64
#  39   RCOP_X             float64
#  40   RCOP_Y             float64
#  41   RCOP_Z             float64
#  42   LCOP_X             float64
#  43   LCOP_Y             float64
#  44   LCOP_Z             float64
#  45   COPNET_X           float64
#  46   COPNET_Y           float64
#  47   COPNET_Z           float64
#  48   RFREEMOMENT_Y      float64
#  49   LFREEMOMENT_Y      float64
#  50   Sp5_Sp4_FE_Z       float64
#  51   Sp4_Sp3_FE_Z       float64
#  52   Sp3_Sp2_FE_Z       float64
#  53   Sp2_Sp1_FE_Z       float64
#  54   Sp1_Pel_FE_Z       float64
#  55   RSp5_Sp4_LB_Z      float64
#  56   LSp5_Sp4_LB_Z      float64
#  57   RSp4_Sp3_LB_Z      float64
#  58   LSp4_Sp3_LB_Z      float64
#  59   RSp3_Sp2_LB_Z      float64
#  60   LSp3_Sp2_LB_Z      float64
#  61   RSp2_Sp1_LB_Z      float64
#  62   LSp2_Sp1_LB_Z      float64
#  63   RSp1_Pel_LB_Z      float64
#  64   LSp1_Pel_LB_Z      float64
#  65   RSh_Th_LB_Z        float64
#  66   LSh_Th_LB_Z        float64
#  67   RSh_Th_AR_Z        float64
#  68   LSh_Th_AR_Z        float64
#  69   RA_Th_Transl_X     float64
#  70   RA_Th_Transl_Y     float64
#  71   RA_Th_Transl_Z     float64
#  72   LA_Th_Transl_X     float64
#  73   LA_Th_Transl_Y     float64
#  74   LA_Th_Transl_Z     float64
#  75   RHe_Th_Angle_X     float64
#  76   RHe_Th_Angle_Y     float64
#  77   RHe_Th_Angle_Z     float64
#  78   LHe_Th_Angle_X     float64
#  79   LHe_Th_Angle_Y     float64
#  80   LHe_Th_Angle_Z     float64
#  81   RTh_Pel_Angle_X    float64
#  82   RTh_Pel_Angle_Y    float64
#  83   RTh_Pel_Angle_Z    float64
#  84   LTh_Pel_Angle_X    float64
#  85   LTh_Pel_Angle_Y    float64
#  86   LTh_Pel_Angle_Z    float64
#  87   RHe_Lab_Angle_X    float64
#  88   RHe_Lab_Angle_Y    float64
#  89   RHe_Lab_Angle_Z    float64
#  90   LHe_Lab_Angle_X    float64
#  91   LHe_Lab_Angle_Y    float64
#  92   LHe_Lab_Angle_Z    float64
#  93   RTh_Lab_Angle_X    float64
#  94   RTh_Lab_Angle_Y    float64
#  95   RTh_Lab_Angle_Z    float64
#  96   LTh_Lab_Angle_X    float64
#  97   LTh_Lab_Angle_Y    float64
#  98   LTh_Lab_Angle_Z    float64
#  99   RPel_Lab_Angle_X   float64
#  100  RPel_Lab_Angle_Y   float64
#  101  RPel_Lab_Angle_Z   float64
#  102  LPel_Lab_Angle_X   float64
#  103  LPel_Lab_Angle_Y   float64
#  104  LPel_Lab_Angle_Z   float64
#  105  RHip_Angle_X       float64
#  106  RHip_Angle_Y       float64
#  107  RHip_Angle_Z       float64
#  108  LHip_Angle_X       float64
#  109  LHip_Angle_Y       float64
#  110  LHip_Angle_Z       float64
#  111  RKnee_Angle_X      float64
#  112  RKnee_Angle_Y      float64
#  113  RKnee_Angle_Z      float64
#  114  LKnee_Angle_X      float64
#  115  LKnee_Angle_Y      float64
#  116  LKnee_Angle_Z      float64
#  117  RAnkle_Angle_X     float64
#  118  RAnkle_Angle_Y     float64
#  119  RAnkle_Angle_Z     float64
#  120  LAnkle_Angle_X     float64
#  121  LAnkle_Angle_Y     float64
#  122  LAnkle_Angle_Z     float64
#  123  R.Front.Head_X     float64
#  124  R.Front.Head_Y     float64
#  125  R.Front.Head_Z     float64
#  126  L.Front.Head_X     float64
#  127  L.Front.Head_Y     float64
#  128  L.Front.Head_Z     float64
#  129  R.Back.Head_X      float64
#  130  R.Back.Head_Y      float64
#  131  R.Back.Head_Z      float64
#  132  L.Back.Head_X      float64
#  133  L.Back.Head_Y      float64
#  134  L.Back.Head_Z      float64
#  135  R.Shoulder_X       float64
#  136  R.Shoulder_Y       float64
#  137  R.Shoulder_Z       float64
#  138  L.Shoulder_X       float64
#  139  L.Shoulder_Y       float64
#  140  L.Shoulder_Z       float64
#  141  C7_X               float64
#  142  C7_Y               float64
#  143  C7_Z               float64
#  144  T2_X               float64
#  145  T2_Y               float64
#  146  T2_Z               float64
#  147  T7_X               float64
#  148  T7_Y               float64
#  149  T7_Z               float64
#  150  L1_X               float64
#  151  L1_Y               float64
#  152  L1_Z               float64
#  153  L3_X               float64
#  154  L3_Y               float64
#  155  L3_Z               float64
#  156  L5_X               float64
#  157  L5_Y               float64
#  158  L5_Z               float64
#  159  IJ_X               float64
#  160  IJ_Y               float64
#  161  IJ_Z               float64
#  162  PX_X               float64
#  163  PX_Y               float64
#  164  PX_Z               float64
#  165  R.ASIS_X           float64
#  166  R.ASIS_Y           float64
#  167  R.ASIS_Z           float64
#  168  L.ASIS_X           float64
#  169  L.ASIS_Y           float64
#  170  L.ASIS_Z           float64
#  171  R.PSIS_X           float64
#  172  R.PSIS_Y           float64
#  173  R.PSIS_Z           float64
#  174  L.PSIS_X           float64
#  175  L.PSIS_Y           float64
#  176  L.PSIS_Z           float64
#  177  L.Iliac.Crestv_X   float64
#  178  L.Iliac.Crestv_Y   float64
#  179  L.Iliac.Crestv_Z   float64
#  180  R.Iliac.Crestv_X   float64
#  181  R.Iliac.Crestv_Y   float64
#  182  R.Iliac.Crestv_Z   float64
#  183  R.GTR_X            float64
#  184  R.GTR_Y            float64
#  185  R.GTR_Z            float64
#  186  L.GTR_X            float64
#  187  L.GTR_Y            float64
#  188  L.GTR_Z            float64
#  189  R.Knee_X           float64
#  190  R.Knee_Y           float64
#  191  R.Knee_Z           float64
#  192  R.Knee.Medialv_X   float64
#  193  R.Knee.Medialv_Y   float64
#  194  R.Knee.Medialv_Z   float64
#  195  L.Knee_X           float64
#  196  L.Knee_Y           float64
#  197  L.Knee_Z           float64
#  198  L.Knee.Medialv_X   float64
#  199  L.Knee.Medialv_Y   float64
#  200  L.Knee.Medialv_Z   float64
#  201  R.HF_X             float64
#  202  R.HF_Y             float64
#  203  R.HF_Z             float64
#  204  L.HF_X             float64
#  205  L.HF_Y             float64
#  206  L.HF_Z             float64
#  207  R.TT_X             float64
#  208  R.TT_Y             float64
#  209  R.TT_Z             float64
#  210  L.TT_X             float64
#  211  L.TT_Y             float64
#  212  L.TT_Z             float64
#  213  R.Ankle_X          float64
#  214  R.Ankle_Y          float64
#  215  R.Ankle_Z          float64
#  216  R.Ankle.Medialv_X  float64
#  217  R.Ankle.Medialv_Y  float64
#  218  R.Ankle.Medialv_Z  float64
#  219  L.Ankle_X          float64
#  220  L.Ankle_Y          float64
#  221  L.Ankle_Z          float64
#  222  L.Ankle.Medialv_X  float64
#  223  L.Ankle.Medialv_Y  float64
#  224  L.Ankle.Medialv_Z  float64
#  225  R.Heel_X           float64
#  226  R.Heel_Y           float64
#  227  R.Heel_Z           float64
#  228  L.Heel_X           float64
#  229  L.Heel_Y           float64
#  230  L.Heel_Z           float64
#  231  R.MT1_X            float64
#  232  R.MT1_Y            float64
#  233  R.MT1_Z            float64
#  234  R.MT2_X            float64
#  235  R.MT2_Y            float64
#  236  R.MT2_Z            float64
#  237  R.MT5_X            float64
#  238  R.MT5_Y            float64
#  239  R.MT5_Z            float64
#  240  L.MT1_X            float64
#  241  L.MT1_Y            float64
#  242  L.MT1_Z            float64
#  243  L.MT2_X            float64
#  244  L.MT2_Y            float64
#  245  L.MT2_Z            float64
#  246  L.MT5_X            float64
#  247  L.MT5_Y            float64
#  248  L.MT5_Z            float64
#  249  COG_X              float64
#  250  COG_Y              float64
#  251  COG_Z              float64
#  252  L.Iliac.Crest_X    float64
#  253  L.Iliac.Crest_Y    float64
#  254  L.Iliac.Crest_Z    float64
#  255  R.Iliac.Crest_X    float64
#  256  R.Iliac.Crest_Y    float64
#  257  R.Iliac.Crest_Z    float64
#  258  R.Knee.Medial_X    float64
#  259  R.Knee.Medial_Y    float64
#  260  R.Knee.Medial_Z    float64
#  261  L.Knee.Medial_X    float64
#  262  L.Knee.Medial_Y    float64
#  263  L.Knee.Medial_Z    float64
#  264  R.Ankle.Medial_X   float64
#  265  R.Ankle.Medial_Y   float64
#  266  R.Ankle.Medial_Z   float64
#  267  L.Ankle.Medial_X   float64
#  268  L.Ankle.Medial_Y   float64
#  269  L.Ankle.Medial_Z   float64
# dtypes: category(29), float64(241)
# memory usage: 6.5 GB

# %% [markdown]
# ### Dos Santos17
# Não iremos ler : ( markers, angs e static)

# %%
# LOCAL Jonatas
path2 = Path(f'D:{os.sep}Datasets{os.sep}dosSantos17{os.sep}data')
os_sep = os.sep
metadata_fname = 'PDSinfo.txt'
print(f'Dataset location: {path2}')
metadata = pd.read_csv(f"{path2}{os.sep}PDSinfo.txt", sep='\t', header=0,
                       engine='c', encoding='utf-8')
print('Information from %s files successfully loaded (total of %s subjects).'
      %(len(metadata), len(pd.unique(metadata.Subject))))
display(metadata)
# Out:
# Dataset location: D:\Datasets\dosSantos17\data
# Information from 588 files successfully loaded (total of 49 subjects).
#         Trial  Subject  Vision Surface  Rep    Age AgeGroup Gender  Height  \
# 0    PDS01OR1        1    Open   Rigid    1  25.67    Young      M    1.72
# 1    PDS01OR2        1    Open   Rigid    2  25.67    Young      M    1.72
# 2    PDS01OR3        1    Open   Rigid    3  25.67    Young      M    1.72
# 3    PDS01OF1        1    Open    Foam    1  25.67    Young      M    1.72
# 4    PDS01OF2        1    Open    Foam    2  25.67    Young      M    1.72
# ..        ...      ...     ...     ...  ...    ...      ...    ...     ...
# 583  PDS49CR2       49  Closed   Rigid    2  64.92      Old      F    1.58
# 584  PDS49CR3       49  Closed   Rigid    3  64.92      Old      F    1.58
# 585  PDS49CF1       49  Closed    Foam    1  64.92      Old      F    1.58
# 586  PDS49CF2       49  Closed    Foam    2  64.92      Old      F    1.58
# 587  PDS49CF3       49  Closed    Foam    3  64.92      Old      F    1.58
#
#       Mass  ...  Nmedication  \
# 0    74.30  ...            0
# 1    74.30  ...            0
# 2    74.30  ...            0
# 3    74.30  ...            0
# 4    74.30  ...            0
# ..     ...  ...          ...
# 583  60.75  ...            3
# 584  60.75  ...            3
# 585  60.75  ...            3
# 586  60.75  ...            3
# 587  60.75  ...            3
#
#                                             Medication Ortho-Prosthesis  \
# 0                                                   No              Yes
# 1                                                   No              Yes
# 2                                                   No              Yes
# 3                                                   No              Yes
# 4                                                   No              Yes
# ..                                                 ...              ...
# 583  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 584  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 585  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 586  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 587  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
#
#                    Ortho-Prosthesis2 Disability         Disability2 Falls12m  \
# 0                    Corrective lens         No                  No        0
# 1                    Corrective lens         No                  No        0
# 2                    Corrective lens         No                  No        0
# 3                    Corrective lens         No                  No        0
# 4                    Corrective lens         No                  No        0
# ..                               ...        ...                 ...      ...
# 583  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 584  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 585  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 586  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 587  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
#
#     PhysicalActivity        Sequence                     Date
# 0                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 1                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 2                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 3                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 4                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# ..               ...             ...                      ...
# 583                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 584                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 585                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 586                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 587                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
#
# [588 rows x 29 columns]

# %%
metadata = pd.read_csv(f'{path2}{os_sep}{metadata_fname}', sep='\t', header=0,
                       engine='c', encoding='utf-8')
print('Information from %s files successfully loaded (total of %s subjects).'
      %(len(metadata), len(pd.unique(metadata.Subject))))
metadata_copy = metadata.copy(deep=True)
display(metadata)
# Out:
# Information from 588 files successfully loaded (total of 49 subjects).
#         Trial  Subject  Vision Surface  Rep    Age AgeGroup Gender  Height  \
# 0    PDS01OR1        1    Open   Rigid    1  25.67    Young      M    1.72
# 1    PDS01OR2        1    Open   Rigid    2  25.67    Young      M    1.72
# 2    PDS01OR3        1    Open   Rigid    3  25.67    Young      M    1.72
# 3    PDS01OF1        1    Open    Foam    1  25.67    Young      M    1.72
# 4    PDS01OF2        1    Open    Foam    2  25.67    Young      M    1.72
# ..        ...      ...     ...     ...  ...    ...      ...    ...     ...
# 583  PDS49CR2       49  Closed   Rigid    2  64.92      Old      F    1.58
# 584  PDS49CR3       49  Closed   Rigid    3  64.92      Old      F    1.58
# 585  PDS49CF1       49  Closed    Foam    1  64.92      Old      F    1.58
# 586  PDS49CF2       49  Closed    Foam    2  64.92      Old      F    1.58
# 587  PDS49CF3       49  Closed    Foam    3  64.92      Old      F    1.58
#
#       Mass  ...  Nmedication  \
# 0    74.30  ...            0
# 1    74.30  ...            0
# 2    74.30  ...            0
# 3    74.30  ...            0
# 4    74.30  ...            0
# ..     ...  ...          ...
# 583  60.75  ...            3
# 584  60.75  ...            3
# 585  60.75  ...            3
# 586  60.75  ...            3
# 587  60.75  ...            3
#
#                                             Medication Ortho-Prosthesis  \
# 0                                                   No              Yes
# 1                                                   No              Yes
# 2                                                   No              Yes
# 3                                                   No              Yes
# 4                                                   No              Yes
# ..                                                 ...              ...
# 583  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 584  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 585  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 586  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 587  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
#
#                    Ortho-Prosthesis2 Disability         Disability2 Falls12m  \
# 0                    Corrective lens         No                  No        0
# 1                    Corrective lens         No                  No        0
# 2                    Corrective lens         No                  No        0
# 3                    Corrective lens         No                  No        0
# 4                    Corrective lens         No                  No        0
# ..                               ...        ...                 ...      ...
# 583  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 584  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 585  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 586  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 587  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
#
#     PhysicalActivity        Sequence                     Date
# 0                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 1                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 2                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 3                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# 4                  1  OR, OF, CF, CR  2016-08-01 11:00:17.753
# ..               ...             ...                      ...
# 583                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 584                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 585                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 586                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 587                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
#
# [588 rows x 29 columns]

# %%
metadata = metadata.astype('category', copy=True)
metadata.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Trial              588 non-null    category
#  1   Subject            588 non-null    category
#  2   Vision             588 non-null    category
#  3   Surface            588 non-null    category
#  4   Rep                588 non-null    category
#  5   Age                588 non-null    category
#  6   AgeGroup           588 non-null    category
#  7   Gender             588 non-null    category
#  8   Height             588 non-null    category
#  9   Mass               588 non-null    category
#  10  BMI                588 non-null    category
#  11  FootLen            588 non-null    category
#  12  DominantLeg        588 non-null    category
#  13  Nationality        588 non-null    category
#  14  SkinColor          588 non-null    category
#  15  Ystudy             588 non-null    category
#  16  Footwear           588 non-null    category
#  17  Illness            588 non-null    category
#  18  Illness2           588 non-null    category
#  19  Nmedication        588 non-null    category
#  20  Medication         588 non-null    category
#  21  Ortho-Prosthesis   588 non-null    category
#  22  Ortho-Prosthesis2  588 non-null    category
#  23  Disability         588 non-null    category
#  24  Disability2        588 non-null    category
#  25  Falls12m           588 non-null    category
#  26  PhysicalActivity   588 non-null    category
#  27  Sequence           588 non-null    category
#  28  Date               588 non-null    category
# dtypes: category(29)
# memory usage: 101.3 KB

# %%
def merge_meta_grf(trial):
    file_endings = ['grf', 'mkr', 'ang', 'static']

    for ending in file_endings:
        arquivo = f'{path2}{os_sep}{trial}{ending}.txt'
        if os.path.isfile(arquivo):
            grf = pd.read_csv(arquivo, delimiter='\t', header=0)
            grf['Trial'] = trial
            return pd.merge(metadata.query('Trial == @trial'), grf, how='inner', on='Trial')

# %%
from tqdm import tqdm
df_all = [merge_meta_grf(trial) for trial in tqdm(metadata['Trial'])]
df_all = pd.concat(df_all, ignore_index=True)
df_all = df_all.astype({'Trial': 'category'})
df_all
# Out:
#   0%|          | 0/588 [00:00<?, ?it/s]
# 100%|██████████| 588/588 [00:55<00:00, 10.64it/s]
#             Trial  Subject  Vision Surface  Rep    Age AgeGroup Gender  \
# 0        PDS01OR1        1    Open   Rigid    1  25.67    Young      M
# 1        PDS01OR1        1    Open   Rigid    1  25.67    Young      M
# 2        PDS01OR1        1    Open   Rigid    1  25.67    Young      M
# 3        PDS01OR1        1    Open   Rigid    1  25.67    Young      M
# 4        PDS01OR1        1    Open   Rigid    1  25.67    Young      M
# ...           ...      ...     ...     ...  ...    ...      ...    ...
# 3527995  PDS49CF3       49  Closed    Foam    3  64.92      Old      F
# 3527996  PDS49CF3       49  Closed    Foam    3  64.92      Old      F
# 3527997  PDS49CF3       49  Closed    Foam    3  64.92      Old      F
# 3527998  PDS49CF3       49  Closed    Foam    3  64.92      Old      F
# 3527999  PDS49CF3       49  Closed    Foam    3  64.92      Old      F
#
#          Height   Mass  ...  RCOP_Y    RCOP_Z    LCOP_X LCOP_Y    LCOP_Z  \
# 0          1.72  74.30  ...     0.0  0.093610  0.227590    0.0 -0.085100
# 1          1.72  74.30  ...     0.0  0.093502  0.227516    0.0 -0.085075
# 2          1.72  74.30  ...     0.0  0.093391  0.227458    0.0 -0.085064
# 3          1.72  74.30  ...     0.0  0.093278  0.227424    0.0 -0.085075
# 4          1.72  74.30  ...     0.0  0.093171  0.227413    0.0 -0.085108
# ...         ...    ...  ...     ...       ...       ...    ...       ...
# 3527995    1.58  60.75  ...     0.0  0.111741  0.295525    0.0 -0.116602
# 3527996    1.58  60.75  ...     0.0  0.111785  0.295505    0.0 -0.116570
# 3527997    1.58  60.75  ...     0.0  0.111849  0.295502    0.0 -0.116534
# 3527998    1.58  60.75  ...     0.0  0.111940  0.295511    0.0 -0.116497
# 3527999    1.58  60.75  ...     0.0  0.112048  0.295525    0.0 -0.116461
#
#          COPNET_X COPNET_Y  COPNET_Z RFREEMOMENT_Y  LFREEMOMENT_Y
# 0        0.231089      0.0 -0.002490      3.067748      -0.889998
# 1        0.230965      0.0 -0.002571      3.058200      -0.873012
# 2        0.230859      0.0 -0.002660      3.050973      -0.858668
# 3        0.230782      0.0 -0.002755      3.047538      -0.849078
# 4        0.230732      0.0 -0.002848      3.047990      -0.845515
# ...           ...      ...       ...           ...            ...
# 3527995  0.277993      0.0  0.011928     -0.829290      -0.148266
# 3527996  0.277949      0.0  0.012094     -0.825005      -0.140185
# 3527997  0.277911      0.0  0.012296     -0.819960      -0.137504
# 3527998  0.277880      0.0  0.012536     -0.814717      -0.140403
# 3527999  0.277853      0.0  0.012802     -0.809514      -0.146761
#
# [3528000 rows x 50 columns]

# %%
df_all.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3528000 entries, 0 to 3527999
# Data columns (total 50 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Trial              category
#  1   Subject            category
#  2   Vision             category
#  3   Surface            category
#  4   Rep                category
#  5   Age                category
#  6   AgeGroup           category
#  7   Gender             category
#  8   Height             category
#  9   Mass               category
#  10  BMI                category
#  11  FootLen            category
#  12  DominantLeg        category
#  13  Nationality        category
#  14  SkinColor          category
#  15  Ystudy             category
#  16  Footwear           category
#  17  Illness            category
#  18  Illness2           category
#  19  Nmedication        category
#  20  Medication         category
#  21  Ortho-Prosthesis   category
#  22  Ortho-Prosthesis2  category
#  23  Disability         category
#  24  Disability2        category
#  25  Falls12m           category
#  26  PhysicalActivity   category
#  27  Sequence           category
#  28  Date               category
#  29  Time               float64
#  30  RGRF_X             float64
#  31  RGRF_Y             float64
#  32  RGRF_Z             float64
#  33  LGRF_X             float64
#  34  LGRF_Y             float64
#  35  LGRF_Z             float64
#  36  GRFNET_X           float64
#  37  GRFNET_Y           float64
#  38  GRFNET_Z           float64
#  39  RCOP_X             float64
#  40  RCOP_Y             float64
#  41  RCOP_Z             float64
#  42  LCOP_X             float64
#  43  LCOP_Y             float64
#  44  LCOP_Z             float64
#  45  COPNET_X           float64
#  46  COPNET_Y           float64
#  47  COPNET_Z           float64
#  48  RFREEMOMENT_Y      float64
#  49  LFREEMOMENT_Y      float64
# dtypes: category(29), float64(21)
# memory usage: 666.3 MB

# %%
df_all.to_parquet(f'{path2}{os_sep}{"santos17grf.parquet"}', engine='fastparquet', index=False)

# %%
df_all2 = pd.read_parquet(f'{path2}{os_sep}{"santos17grf.parquet"}', engine='fastparquet')
df_all2
# Out:
#             Trial Subject  Vision Surface Rep    Age AgeGroup Gender Height  \
# 0        PDS01OR1       1    Open   Rigid   1  25.67    Young      M   1.72
# 1        PDS01OR1       1    Open   Rigid   1  25.67    Young      M   1.72
# 2        PDS01OR1       1    Open   Rigid   1  25.67    Young      M   1.72
# 3        PDS01OR1       1    Open   Rigid   1  25.67    Young      M   1.72
# 4        PDS01OR1       1    Open   Rigid   1  25.67    Young      M   1.72
# ...           ...     ...     ...     ...  ..    ...      ...    ...    ...
# 3527995  PDS49CF3      49  Closed    Foam   3  64.92      Old      F   1.58
# 3527996  PDS49CF3      49  Closed    Foam   3  64.92      Old      F   1.58
# 3527997  PDS49CF3      49  Closed    Foam   3  64.92      Old      F   1.58
# 3527998  PDS49CF3      49  Closed    Foam   3  64.92      Old      F   1.58
# 3527999  PDS49CF3      49  Closed    Foam   3  64.92      Old      F   1.58
#
#           Mass  ... RCOP_Y    RCOP_Z    LCOP_X LCOP_Y    LCOP_Z  COPNET_X  \
# 0        74.30  ...    0.0  0.093610  0.227590    0.0 -0.085100  0.231089
# 1        74.30  ...    0.0  0.093502  0.227516    0.0 -0.085075  0.230965
# 2        74.30  ...    0.0  0.093391  0.227458    0.0 -0.085064  0.230859
# 3        74.30  ...    0.0  0.093278  0.227424    0.0 -0.085075  0.230782
# 4        74.30  ...    0.0  0.093171  0.227413    0.0 -0.085108  0.230732
# ...        ...  ...    ...       ...       ...    ...       ...       ...
# 3527995  60.75  ...    0.0  0.111741  0.295525    0.0 -0.116602  0.277993
# 3527996  60.75  ...    0.0  0.111785  0.295505    0.0 -0.116570  0.277949
# 3527997  60.75  ...    0.0  0.111849  0.295502    0.0 -0.116534  0.277911
# 3527998  60.75  ...    0.0  0.111940  0.295511    0.0 -0.116497  0.277880
# 3527999  60.75  ...    0.0  0.112048  0.295525    0.0 -0.116461  0.277853
#
#         COPNET_Y  COPNET_Z RFREEMOMENT_Y LFREEMOMENT_Y
# 0            0.0 -0.002490      3.067748     -0.889998
# 1            0.0 -0.002571      3.058200     -0.873012
# 2            0.0 -0.002660      3.050973     -0.858668
# 3            0.0 -0.002755      3.047538     -0.849078
# 4            0.0 -0.002848      3.047990     -0.845515
# ...          ...       ...           ...           ...
# 3527995      0.0  0.011928     -0.829290     -0.148266
# 3527996      0.0  0.012094     -0.825005     -0.140185
# 3527997      0.0  0.012296     -0.819960     -0.137504
# 3527998      0.0  0.012536     -0.814717     -0.140403
# 3527999      0.0  0.012802     -0.809514     -0.146761
#
# [3528000 rows x 50 columns]

# %%
df_all2.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3528000 entries, 0 to 3527999
# Data columns (total 50 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Trial              category
#  1   Subject            category
#  2   Vision             category
#  3   Surface            category
#  4   Rep                category
#  5   Age                category
#  6   AgeGroup           category
#  7   Gender             category
#  8   Height             category
#  9   Mass               category
#  10  BMI                category
#  11  FootLen            category
#  12  DominantLeg        category
#  13  Nationality        category
#  14  SkinColor          category
#  15  Ystudy             category
#  16  Footwear           category
#  17  Illness            category
#  18  Illness2           category
#  19  Nmedication        category
#  20  Medication         category
#  21  Ortho-Prosthesis   category
#  22  Ortho-Prosthesis2  category
#  23  Disability         category
#  24  Disability2        category
#  25  Falls12m           category
#  26  PhysicalActivity   category
#  27  Sequence           category
#  28  Date               category
#  29  Time               float64
#  30  RGRF_X             float64
#  31  RGRF_Y             float64
#  32  RGRF_Z             float64
#  33  LGRF_X             float64
#  34  LGRF_Y             float64
#  35  LGRF_Z             float64
#  36  GRFNET_X           float64
#  37  GRFNET_Y           float64
#  38  GRFNET_Z           float64
#  39  RCOP_X             float64
#  40  RCOP_Y             float64
#  41  RCOP_Z             float64
#  42  LCOP_X             float64
#  43  LCOP_Y             float64
#  44  LCOP_Z             float64
#  45  COPNET_X           float64
#  46  COPNET_Y           float64
#  47  COPNET_Z           float64
#  48  RFREEMOMENT_Y      float64
#  49  LFREEMOMENT_Y      float64
# dtypes: category(29), float64(21)
# memory usage: 666.3 MB
